# %% [markdown]
# 1.

# %%
x=int(input("enter the number"))
a=x%2
if a!=0:
  print("it is prime number")
elif x/3==0:
  print("it is divisible by 3")
elif x/7==0:
  print("it is divisible by 7")
elif x/9==0:
  print("it is divisible by 9")
elif x/11==0:
  print("it is divisible by 11")
else:
  print("not a prime nor divisible by 3,7,9,11")
# Out:
# enter the number4
# not a prime nor divisible by 3,7,9,11

# %% [markdown]
# 2.

# %%
userinput=input("Enter the string ")
a=len(userinput)
for i in range(x):
  if(userinput[i]!=userinput[x-i-1]):
   print("The userinput is not palindrme")
else:
  print("The userinput is a palindrme")
# Out:
# Enter the string gadag
# The userinput is a palindrme

# %% [markdown]
# 3.

# %%
lis1=[]
lis2=[]
for x in range(5):
 a=int(input("Enter the numbers"))
 if(a%2==0):
     lis1.append(a)
 else:
    lis2.append(a)
print("even no list is")
print(lis1)
print("odd no list is")
print(lis2)
# Out:
# Enter the numbers3
# Enter the numbers4
# Enter the numbers5
# Enter the numbers6
# Enter the numbers7
# even no list is
# [4, 6]
# odd no list is
# [3, 5, 7]

# %% [markdown]
# 4.

# %%
a=int(input("enter no of rows"))
for x in range(1,a+1):
  print("*" *x)
# Out:
# enter no of rows4
# *
# **
# ***
# ****
