# %% [markdown]
# simple linear regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,9,12,14,18])

plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='blue',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 0.5056719506337065
# intercept 3.938587739718434
# slope [0.31193881]

# %% [markdown]
# generating random values and implementing lr

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

x=np.random.randint(1,20,6).reshape((-1,1))
y=np.random.randint(1,20,6)

plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Purple',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 17.663290569435066
# intercept 13.483457123565158
# slope [-0.31195138]

# %% [markdown]
# read an excel sheet and fetch value and repeat linear regression.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

data=pd.read_csv('/content/drive/MyDrive/items12 - Sheet1.csv')
x=np.array(data['unitcost']).reshape((-1,1))
y=np.array(data['totalcost'])

plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Purple',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 123.33333333333333
# intercept 27.77777777777778
# slope [1.11111111]

# %% [markdown]
# multivariate lr

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

data=pd.read_csv('/content/drive/MyDrive/items12 - Sheet1.csv')
x1=np.array(data['unitcost']).reshape((-1,1))
x2=np.array(data['totalcost']).reshape((-1,1))
y=np.array(data['quantity'])

plt.plot(x1,x2,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x1,x2,y)
pred=SLR.predict(x1)
pred=SLR.predict(x2)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x1,x2,pred,color='Purple',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 4414.722222222224
# intercept [30.55555556]
# slope [[1.38888889]]

# %% [markdown]
# correlation between the features

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/items12 - Sheet1.csv')
data.corr()
# Out:
# <ipython-input-7-8484c477c153>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#            quantity  unitcost  totalcost
# quantity   1.000000 -0.745356   0.487950
# unitcost  -0.745356  1.000000   0.145479
# totalcost  0.487950  0.145479   1.000000

# %% [markdown]
# polynomial regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

data=pd.read_csv('/content/drive/MyDrive/items12 - Sheet1.csv')
x=np.array(data['unitcost']).reshape((-1,1))
y=np.array(data['totalcost'])

plt.scatter(x**2,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x**2,y)
pred=SLR.predict(x**2)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Purple',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 123.33333333333333
# intercept 29.365079365079364
# slope [0.15873016]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

data=pd.read_csv('/content/drive/MyDrive/items12 - Sheet1.csv')
x1=np.array(data['unitcost']).reshape((-1,1))
x2=np.array(data['totalcost']).reshape((-1,1))
y=np.array(data['quantity'])

plt.plot(x1**2,x2,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x1**2,x2,y)
pred=SLR.predict(x1**2)
pred=SLR.predict(x2)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x1*2,x2,pred,color='blue',marker='')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 857.6234567901234
# intercept [32.53968254]
# slope [[0.1984127]]

# %% [markdown]
# gradient descent

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data for linear regression
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)


def compute_cost(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))
    return cost

def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for _ in range(num_iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        gradient = (1 / m) * X.T.dot(errors)
        theta -= learning_rate * gradient
        cost = compute_cost(theta, X, y)
        cost_history.append(cost)

    return theta, cost_history


# Add bias term to the features
X_b = np.c_[np.ones((100, 1)), X]

# Initialize theta and hyperparameters
theta = np.random.randn(2, 1)
learning_rate = 0.1
num_iterations = 100

# Run gradient descent
theta_updated, cost_history = gradient_descent(X_b, y, theta, learning_rate, num_iterations)


plt.plot(cost_history)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost History')
plt.show()
